# %%
import pandas as pd
import numpy as np
import random
from collections import defaultdict
from datetime import timedelta
import math

# %%
# Cargar archivo Excel
file_path = "generic_input_case.xlsx"

# Leer cada hoja
df_horizonte = pd.read_excel(file_path, sheet_name="HORIZONTE")
df_bd_up = pd.read_excel(file_path, sheet_name="BD_UP")
df_frota = pd.read_excel(file_path, sheet_name="FROTA")
df_grua = pd.read_excel(file_path, sheet_name="GRUA")
df_fabrica = pd.read_excel(file_path, sheet_name="FABRICA")
df_rota = pd.read_excel(file_path, sheet_name="ROTA")

# df_horizonte=df_horizonte.iloc[0:5]
# df_horizonte=df_horizonte.iloc[0:5]
# Out:
# c:\Users\wilma\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
# Asumiendo que los DataFrames (df_horizonte, df_bd_up, etc.) ya están cargados
# con el código de la sección anterior.

# Crear una copia de df_bd_up para rastrear el volumen restante
df_up_remaining = df_bd_up.copy()
df_up_remaining['VOLUME_RESTANTE'] = df_up_remaining['VOLUME']

# Lista para almacenar las filas de la solución
solucion_inicial = []

# Obtener la lista de días y transportadores
dias_planificacion = df_horizonte['DIA'].unique()
transportadores = df_frota['TRANSPORTADOR'].unique()
ups_disponibles = df_up_remaining['UP'].tolist() # Lista inicial de UPs

# --- Lógica Greedy Muy Simplificada ---
for dia in dias_planificacion:
    print(f"\nProcesando Dia: {dia}")
    # Obtener info del día (ej. si es ciclo lento)
    # es_ciclo_lento = df_horizonte[df_horizonte['DIA'] == dia]['CICLO_LENTO'].iloc[0] == 'X' # Lógica ejemplo

    for transportador in transportadores:
        # Obtener info del transportador (min/max flota, grúas)
        frota_info = df_frota[df_frota['TRANSPORTADOR'] == transportador].iloc[0]
        grua_info = df_grua[df_grua['TRANSPORTADOR'] == transportador].iloc[0]
        frota_min = frota_info['FROTA_MIN']
        frota_max = frota_info['FROTA_MAX'] # No usado en esta lógica simple
        # qtd_gruas = grua_info['QTD_GRUAS'] # No usado en esta lógica simple

        # Decisión MUY simple: Asignar un número fijo (mínimo) de vehículos
        vehiculos_asignados_total = random.randint(frota_min,frota_max)

        # Decisión MUY simple: Intentar asignar algunas UPs disponibles
        # (Sin considerar Fazenda, grúas, completitud, etc.)
        ups_a_intentar = random.sample(ups_disponibles, min(len(ups_disponibles), 2)) # Ej: intentar 2 UPs al azar

        vehiculos_por_up = vehiculos_asignados_total // len(ups_a_intentar) if ups_a_intentar else 0

        for up_id in ups_a_intentar:
            if vehiculos_por_up == 0: continue

            # Obtener info de la UP y la ruta (si existe)
            up_info = df_up_remaining[df_up_remaining['UP'] == up_id]
            if up_info.empty or up_info['VOLUME_RESTANTE'].iloc[0] <= 0:
                continue # Saltar si la UP no existe o ya está vacía

            rota_info = df_rota[(df_rota['ORIGEM'] == up_id) & (df_rota['TRANSPORTADOR'] == transportador)]
            if rota_info.empty:
                # print(f"Advertencia: No se encontró ruta para {up_id} con {transportador}")
                continue # Saltar si no hay ruta definida

            # Extraer datos necesarios
            fazenda = up_info['FAZENDA'].iloc[0]
            db = up_info['DB'].iloc[0]
            rsp = up_info['RSP'].iloc[0]
            caixa_carga = rota_info['CAIXA_CARGA'].iloc[0]
            tempo_ciclo = rota_info['TEMPO_CICLO'].iloc[0]
            # Aquí se podría ajustar tempo_ciclo si es_ciclo_lento

            # Calcular volumen transportado (simplificado)
            volumen_transportado_up = vehiculos_por_up * caixa_carga * tempo_ciclo

            # Limitar al volumen restante en la UP
            volumen_restante_up = up_info['VOLUME_RESTANTE'].iloc[0]
            volumen_real_transportado = min(volumen_transportado_up, volumen_restante_up)

            # Actualizar volumen restante
            df_up_remaining.loc[df_up_remaining['UP'] == up_id, 'VOLUME_RESTANTE'] -= volumen_real_transportado

            # Añadir a la solución si se transportó algo
            if volumen_real_transportado > 0:
                solucion_inicial.append({
                    'UP': up_id,
                    'FAZENDA': fazenda,
                    'TRANSPORTADOR': transportador,
                    'DIA': dia,
                    'MES': df_horizonte[df_horizonte['DIA'] == dia]['MES'].iloc[0], # Asumiendo un solo mes
                    'DB': db,
                    'RSP': rsp,
                    'QTD_VEICULOS': vehiculos_por_up, # OJO: Es la asignación, no necesariamente los usados óptimamente
                    'VOLUME': volumen_real_transportado
                })

            # Remover UP si se completó (simplificado)
            if df_up_remaining.loc[df_up_remaining['UP'] == up_id, 'VOLUME_RESTANTE'].iloc[0] <= 0:
                 if up_id in ups_disponibles:
                     ups_disponibles.remove(up_id)


# Convertir la lista de diccionarios a un DataFrame
df_solucion_inicial = pd.DataFrame(solucion_inicial)

# --- Mostrar Solución Inicial (ejemplo) ---
print("\n--- Solución Inicial Generada (Ejemplo Muy Básico) ---")
print(df_solucion_inicial.head(20))

# --- Guardar a CSV (opcional) ---
# df_solucion_inicial.to_csv("solucion_inicial.csv", index=False, sep=';', decimal=',')
# print("\nSolución inicial guardada en 'solucion_inicial.csv'")
# Out:
# Procesando Dia: 1
#
# Procesando Dia: 2
#
# Procesando Dia: 3
#
# Procesando Dia: 4
#
# Procesando Dia: 5
#
# Procesando Dia: 6
#
# Procesando Dia: 7
#
# Procesando Dia: 8
#
# Procesando Dia: 9
#
# Procesando Dia: 10
#
# Procesando Dia: 11
#
# Procesando Dia: 12
#
# Procesando Dia: 13
#
# Procesando Dia: 14
#
# Procesando Dia: 15
#
# Procesando Dia: 16
#
# Procesando Dia: 17
#
# Procesando Dia: 18
#
# Procesando Dia: 19
#
# Procesando Dia: 20
#
# Procesando Dia: 21
#
# Procesando Dia: 22
#
# Procesando Dia: 23
#
# Procesando Dia: 24
#
# Procesando Dia: 25
#
# Procesando Dia: 26
#
# Procesando Dia: 27
#
# Procesando Dia: 28
#
# Procesando Dia: 29
#
# Procesando Dia: 30
#
# Procesando Dia: 31
#
# --- Solución Inicial Generada (Ejemplo Muy Básico) ---
#         UP                      FAZENDA TRANSPORTADOR  DIA  MES          DB  \
# 0   S5AW13  PIRACEMA_GLEBA PULADOR - DX       Pastori    1    5  471.883265
# 1   S6BX01         SANTO ANTONIO SALIG.         Tover    1    5  450.000000
# 2   S3AX06                   INDIANA II       Rampazo    1    5  473.890188
# 3   S5AW10  PIRACEMA_GLEBA PULADOR - DX       Rampazo    1    5  489.657814
# 4   S5AK05              TURVO III (LEX)       Pastori    2    5  493.203247
# 5   S3AX01                   INDIANA II       Pastori    2    5  476.359312
# 6   S6BG12                      SINIMBU         Tover    2    5  478.190743
# 7   S5AW09  PIRACEMA_GLEBA PULADOR - DX       Rampazo    2    5  485.300233
# 8   S6BG13                      SINIMBU         Tover    3    5  482.776944
# 9   S6C298                    FORTALEZA         Tover    3    5  475.592290
# 10  S5AW14  PIRACEMA_GLEBA PULADOR - DX       Rampazo    3    5  467.553351
# 11  S3AX03                   INDIANA II       Pastori    4    5  410.081889
# 12  S5AW10  PIRACEMA_GLEBA PULADOR - DX       Pastori    4    5  489.657814
# 13  S5AK08              TURVO III (LEX)       Rampazo    4    5  484.253826
# 14  S5AW14  PIRACEMA_GLEBA PULADOR - DX       Pastori    5    5  467.553351
# 15  S6C298                    FORTALEZA         Tover    5    5  475.592290
# 16  S5AK10              TURVO III (LEX)       Rampazo    5    5  494.987423
# 17  S5AW14  PIRACEMA_GLEBA PULADOR - DX       Pastori    6    5  467.553351
# 18  S5AK10              TURVO III (LEX)       Pastori    6    5  494.987423
# 19  S6BG13                      SINIMBU         Tover    6    5  482.776944
#
#          RSP  QTD_VEICULOS  VOLUME
# 0   1.410163            12  1188.0
# 1   1.440000             6   871.2
# 2   1.550207             9  1069.2
# 3   1.441440             9   891.0
# 4   1.479045            13  1201.2
# 5   1.546497            13  1544.4
# 6   1.532140             7  1155.0
# 7   1.403137            10   990.0
# 8   1.562194             7  1155.0
# 9   1.622175             7   970.2
# 10  1.378530            10   990.0
# 11  1.302226            13  1544.4
# 12  1.441440            13  1287.0
# 13  1.515094             9   831.6
# 14  1.378530            13  1287.0
# 15  1.622175             7   970.2
# 16  1.443982            10   924.0
# 17  1.378530            12  1188.0
# 18  1.443982            12  1108.8
# 19  1.562194             7  1155.0

# %%
# --- Funciones de Validación de Restricciones ---

def validate_daily_demand(schedule_df, df_fabrica):
    """Verifica si el volumen diario entregado está dentro de los límites."""
    daily_volume = schedule_df.groupby('DIA')['VOLUME'].sum()
    merged = pd.merge(daily_volume.reset_index(), df_fabrica[['DIA', 'DEMANDA_MIN', 'DEMANDA_MAX']], on='DIA')

    violations = merged[
        (merged['VOLUME'] < merged['DEMANDA_MIN']) |
        (merged['VOLUME'] > merged['DEMANDA_MAX'])
    ]

    if not violations.empty:
        print("Incumplimiento - Demanda Diaria:")
        print(violations)
        return False
    return True

def validate_daily_rsp(schedule_df, df_fabrica):
    """Verifica si el RSP promedio ponderado diario está dentro de los límites."""
    if schedule_df.empty or 'VOLUME' not in schedule_df.columns or 'RSP' not in schedule_df.columns:
        return True # No hay datos para validar

    schedule_df['RSP_WEIGHTED_SUM'] = schedule_df['RSP'] * schedule_df['VOLUME']
    daily_rsp_sum = schedule_df.groupby('DIA')['RSP_WEIGHTED_SUM'].sum()
    daily_volume_sum = schedule_df.groupby('DIA')['VOLUME'].sum()

    # Evitar división por cero si un día no tiene volumen
    daily_avg_rsp = (daily_rsp_sum / daily_volume_sum).fillna(0).reset_index()
    daily_avg_rsp.rename(columns={0: 'RSP_AVG'}, inplace=True)

    merged = pd.merge(daily_avg_rsp, df_fabrica[['DIA', 'RSP_MIN', 'RSP_MAX']], on='DIA')

    # Añadir tolerancia pequeña para comparaciones de punto flotante
    tolerance = 1e-6
    violations = merged[
        (merged['RSP_AVG'] < merged['RSP_MIN'] - tolerance) |
        (merged['RSP_AVG'] > merged['RSP_MAX'] + tolerance)
    ]
     # Limpiar columna auxiliar
    # schedule_df.drop(columns=['RSP_WEIGHTED_SUM'], inplace=True, errors='ignore')


    if not violations.empty:
        print("Incumplimiento - RSP Diario:")
        print(violations)
        return False
    return True

def validate_transporter_fleet_size(schedule_df, df_frota):
    """Verifica si la flota diaria por transportador está dentro de los límites."""
    # Asegúrate de contar vehículos únicos por transportador y día
    daily_fleet = schedule_df.groupby(['DIA', 'TRANSPORTADOR'])['QTD_VEICULOS'].sum().reset_index() # Suma todos los vehiculos asignados por transportador en el día. OJO: esto asume que QTD_VEICULOS es el total por asignación UP-Transp-Dia

    # Necesitamos comparar contra FROTA_MIN y FROTA_MAX por transportador
    # df_frota no tiene DIA, se aplica a todos los días
    merged = pd.merge(daily_fleet, df_frota[['TRANSPORTADOR', 'FROTA_MIN', 'FROTA_MAX']], on='TRANSPORTADOR')

    violations = merged[
        (merged['QTD_VEICULOS'] < merged['FROTA_MIN']) |
        (merged['QTD_VEICULOS'] > merged['FROTA_MAX'])
    ]

    if not violations.empty:
        print("Incumplimiento - Tamaño Flota Transportador:")
        print(violations)
        return False
    return True

def validate_crane_capacity(schedule_df, df_grua):
    """Verifica si un transportador atiende más UPs simultáneas que sus grúas."""
    # Contar UPs únicas atendidas por cada transportador cada día
    daily_up_count = schedule_df.groupby(['DIA', 'TRANSPORTADOR'])['UP'].nunique().reset_index()
    daily_up_count.rename(columns={'UP': 'UP_COUNT'}, inplace=True)

    merged = pd.merge(daily_up_count, df_grua[['TRANSPORTADOR', 'QTD_GRUAS']], on='TRANSPORTADOR')

    violations = merged[merged['UP_COUNT'] > merged['QTD_GRUAS']]

    if not violations.empty:
        print("Incumplimiento - Capacidad Grúas:")
        print(violations)
        return False
    return True

def validate_fazenda_exclusivity(schedule_df):
    """Verifica si un transportador opera en más de una Fazenda por día."""
    daily_fazenda_count = schedule_df.groupby(['DIA', 'TRANSPORTADOR'])['FAZENDA'].nunique().reset_index()
    daily_fazenda_count.rename(columns={'FAZENDA': 'FAZENDA_COUNT'}, inplace=True)

    violations = daily_fazenda_count[daily_fazenda_count['FAZENDA_COUNT'] > 1]

    if not violations.empty:
        print("Incumplimiento - Exclusividad Fazenda:")
        print(violations)
        return False
    return True

def validate_min_vehicles_per_up(schedule_df, df_grua):
    """Verifica el porcentaje mínimo de vehículos asignados a una UP."""
    # Calcular flota total por transportador por día
    total_daily_fleet = schedule_df.groupby(['DIA', 'TRANSPORTADOR'])['QTD_VEICULOS'].sum().reset_index()
    total_daily_fleet.rename(columns={'QTD_VEICULOS': 'TOTAL_VEHICULOS_DIA'}, inplace=True)

    # Unir con la asignación por UP y la info de grúa
    merged = pd.merge(schedule_df, total_daily_fleet, on=['DIA', 'TRANSPORTADOR'])
    merged = pd.merge(merged, df_grua[['TRANSPORTADOR', 'PORCENTAGEM_VEICULOS_MIN']], on='TRANSPORTADOR')

    # Calcular porcentaje real
    merged['PORCENTAJE_REAL'] = merged['QTD_VEICULOS'] / merged['TOTAL_VEHICULOS_DIA']

    # Añadir tolerancia pequeña
    tolerance = 1e-6
    violations = merged[merged['PORCENTAJE_REAL'] < merged['PORCENTAGEM_VEICULOS_MIN'] - tolerance]

    if not violations.empty:
        print("Incumplimiento - Vehículos Mínimos por UP:")
        # Mostrar solo columnas relevantes para la violación
        print(violations[['DIA', 'TRANSPORTADOR', 'UP', 'QTD_VEICULOS', 'TOTAL_VEHICULOS_DIA', 'PORCENTAGEM_VEICULOS_MIN', 'PORCENTAJE_REAL']])
        return False
    return True

# --- Funciones de Validación de Completitud (Más Complejas) ---
# Estas requieren analizar el historial a través de los días

def check_continuity(days_list):
    """Función auxiliar para verificar continuidad y número de bloques."""
    if not days_list:
        return 0, True # 0 bloques, continuo
    
    sorted_days = sorted(list(set(days_list)))
    if not sorted_days:
      return 0, True

    blocks = 0
    is_continuous = True
    if sorted_days:
        blocks = 1
        for i in range(len(sorted_days) - 1):
            if sorted_days[i+1] != sorted_days[i] + 1:
                blocks += 1
                is_continuous = False # Hay un salto
    return blocks, is_continuous

def validate_completion_rules(schedule_df, df_bd_up):
    """Valida las reglas de transporte completo/fraccionado para UPs y Fazendas."""
    all_valid = True
    total_volume_transported = schedule_df.groupby('UP')['VOLUME'].sum()
    
    # 1. Validación por UP
    for up_id, group in schedule_df.groupby('UP'):
        up_info = df_bd_up[df_bd_up['UP'] == up_id].iloc[0]
        total_volume_up = up_info['VOLUME']
        volume_transported_up = total_volume_transported.get(up_id, 0)
        days_worked = group['DIA'].tolist()
        num_blocks, is_continuous = check_continuity(days_worked)

        is_small_up = total_volume_up < 7000

        # Regla UP Pequeña (<7000 m³)
        if is_small_up:
            # Debe ser transportada completamente si se empezó
            if 0 < volume_transported_up < total_volume_up:
                 print(f"Incumplimiento UP < 7000: UP {up_id} iniciada pero no completada. Transportado: {volume_transported_up:.2f}, Total: {total_volume_up:.2f}")
                 all_valid = False
            # Debe tener solo 1 entrada (ser continua)
            if num_blocks > 1:
                 print(f"Incumplimiento UP < 7000: UP {up_id} tiene {num_blocks} entradas (debe ser 1). Días: {sorted(list(set(days_worked)))}")
                 all_valid = False

        # Regla UP Grande (>=7000 m³)
        else:
            # Puede tener hasta 2 entradas
            if num_blocks > 2:
                 print(f"Incumplimiento UP >= 7000: UP {up_id} tiene {num_blocks} entradas (máximo 2). Días: {sorted(list(set(days_worked)))}")
                 all_valid = False

    # 2. Validación por Fazenda (Simplificada: verifica si fue completada si se inició)
    # Una validación completa requeriría verificar si el transportador cambió *antes* de completar.
    # Esta versión solo chequea si el volumen total fue transportado al final del horizonte.
    fazenda_volume_transported = schedule_df.groupby('FAZENDA')['VOLUME'].sum()
    # Calcular volumen total por Fazenda desde BD_UP
    fazenda_total_volume = df_bd_up.groupby('FAZENDA')['VOLUME'].sum()

    for fazenda, transported in fazenda_volume_transported.items():
        total = fazenda_total_volume.get(fazenda, 0)
        # Si se transportó algo pero no todo, es una violación potencial (simplificada)
        # La regla estricta es más compleja de verificar sin seguir estados diarios.
        if 0 < transported < total:
            # Esto es una indicación, no una prueba definitiva de violación de la regla *durante* la ejecución
            print(f"Advertencia - Completitud Fazenda: Fazenda {fazenda} iniciada pero no completada al final del horizonte. Transportado: {transported:.2f}, Total: {total:.2f}")
            # all_valid = False # Podrías marcarlo como inválido aquí si quieres ser estricto con el resultado final

    return all_valid


# --- Función Principal de Validación ---
def validate_all_constraints(schedule_df, df_fabrica, df_frota, df_grua, df_bd_up):
    """Ejecuta todas las validaciones."""
    print("--- Iniciando Validación de Restricciones ---")
    is_feasible = True

    # Limpiar columna auxiliar de RSP si existe de ejecuciones anteriores
    if 'RSP_WEIGHTED_SUM' in schedule_df.columns:
        schedule_df.drop(columns=['RSP_WEIGHTED_SUM'], inplace=True, errors='ignore')

    if not validate_daily_demand(schedule_df, df_fabrica): is_feasible = False
    if not validate_daily_rsp(schedule_df, df_fabrica): is_feasible = False
    if not validate_transporter_fleet_size(schedule_df, df_frota): is_feasible = False
    if not validate_crane_capacity(schedule_df, df_grua): is_feasible = False
    if not validate_fazenda_exclusivity(schedule_df): is_feasible = False
    # OJO: La validación de min_vehicles_per_up puede fallar si hay días/transportadores sin asignaciones en schedule_df
    # Se necesita asegurar que schedule_df contenga todas las asignaciones relevantes.
    # if not validate_min_vehicles_per_up(schedule_df, df_grua): is_feasible = False # Puede necesitar ajustes
    if not validate_completion_rules(schedule_df, df_bd_up): is_feasible = False

    print("--- Validación Terminada ---")
    if is_feasible:
        print(">>> La solución CUMPLE con todas las restricciones verificadas.")
    else:
        print(">>> La solución NO CUMPLE con una o más restricciones.")

    return is_feasible

# %%
# --- Ejemplo de Uso (necesitas df_solucion_inicial de la respuesta anterior) ---
# Asumiendo que df_solucion_inicial existe y los otros DataFrames están cargados
print("\nValidando la solución inicial generada:")
validate_all_constraints(df_solucion_inicial, df_fabrica, df_frota, df_grua, df_bd_up)
# Out:
# Validando la solución inicial generada:
# --- Iniciando Validación de Restricciones ---
# Incumplimiento - Demanda Diaria:
#     DIA   VOLUME  DEMANDA_MIN  DEMANDA_MAX
# 0     1  4019.40         6400         8000
# 1     2  4890.60         6400         8000
# 2     3  3115.20         6400         8000
# 3     4  3663.00         6400         8000
# 4     5  3181.20         6400         8000
# 5     6  4342.80         6400         8000
# 6     7  3656.20         6400         8000
# 7     8  4593.60         6400         8000
# 8     9  5794.80         6400         8000
# 9    10  3450.67         6400         8000
# 10   11  3735.60         6400         8000
# 11   12  4166.00         6400         8000
# 12   13  3280.20         6400         8000
# 13   14  1287.00         6400         8000
# 14   15  5082.00         6400         8000
# 15   16  1001.00         6400         8000
# 16   17  3059.20         6400         8000
# 17   18  2100.49         6400         8000
# 18   19  4369.20         6400         8000
# 19   20  4877.20         6400         8000
# 20   21  5478.00         6400         8000
# 21   22  1203.00         6400         8000
# 22   23  3392.40         6400         8000
# 23   24  2626.80         6400         8000
# 24   25  3022.80         6400         8000
# 25   26  5233.80         6400         8000
# 26   27  3484.80         6400         8000
# 27   28  3458.40         6400         8000
# 28   29  3115.20         6400         8000
# 29   30  1960.20         6400         8000
# 30   31  3115.20         6400         8000
# Incumplimiento - RSP Diario:
#     DIA   RSP_AVG  RSP_MIN  RSP_MAX
# 1     2  1.497519      1.4     1.49
# 2     3  1.522507      1.4     1.49
# 3     4  1.399466      1.4     1.49
# 6     7  1.520113      1.4     1.49
# 8     9  1.523024      1.4     1.49
# 14   15  1.515623      1.4     1.49
# 15   16  1.397095      1.4     1.49
# 17   18  1.491677      1.4     1.49
# 18   19  1.385879      1.4     1.49
# 20   21  1.534335      1.4     1.49
# 23   24  1.499074      1.4     1.49
# 24   25  1.506277      1.4     1.49
# 27   28  1.528772      1.4     1.49
# Incumplimiento - Tamaño Flota Transportador:
#     DIA TRANSPORTADOR  QTD_VEICULOS  FROTA_MIN  FROTA_MAX
# 0     1       Pastori            12         25         27
# 3     5       Pastori            13         25         27
# 4     6       Pastori            24         25         27
# 8    10       Pastori            12         25         27
# 10   12       Pastori            12         25         27
# 11   13       Pastori            13         25         27
# 12   14       Pastori            13         25         27
# 13   15       Pastori            12         25         27
# 14   17       Pastori            13         25         27
# 16   20       Pastori            13         25         27
# 17   21       Pastori            13         25         27
# 18   22       Pastori            13         25         27
# 20   25       Pastori            12         25         27
# 22   27       Pastori            13         25         27
# 23   28       Pastori            24         25         27
# 24   29       Pastori            13         25         27
# 25   31       Pastori            12         25         27
# 26    1       Rampazo            18         19         21
# 27    2       Rampazo            10         19         21
# 28    3       Rampazo            10         19         21
# 29    4       Rampazo             9         19         21
# 30    5       Rampazo            10         19         21
# 31    6       Rampazo             9         19         21
# 32    8       Rampazo            10         19         21
# 33    9       Rampazo            10         19         21
# 34   10       Rampazo            18         19         21
# 36   13       Rampazo            10         19         21
# 38   16       Rampazo             9         19         21
# 39   17       Rampazo            10         19         21
# 40   18       Rampazo            10         19         21
# 41   19       Rampazo             9         19         21
# 44   22       Rampazo             9         19         21
# 45   23       Rampazo            10         19         21
# 46   24       Rampazo            10         19         21
# 47   25       Rampazo            10         19         21
# 48   26       Rampazo            10         19         21
# 49   28       Rampazo            10         19         21
# 51   30       Rampazo            18         19         21
# 52   31       Rampazo            10         19         21
# 53    1         Tover             6         12         14
# 54    2         Tover             7         12         14
# 56    5         Tover             7         12         14
# 57    6         Tover             7         12         14
# 58    7         Tover             7         12         14
# 59    8         Tover             6         12         14
# 61   10         Tover             7         12         14
# 62   11         Tover             6         12         14
# 63   12         Tover             7         12         14
# 64   13         Tover             7         12         14
# 66   16         Tover             6         12         14
# 67   17         Tover             6         12         14
# 68   18         Tover             7         12         14
# 69   19         Tover             6         12         14
# 72   22         Tover             7         12         14
# 74   25         Tover             6         12         14
# 77   31         Tover             7         12         14
# Incumplimiento - Exclusividad Fazenda:
#     DIA TRANSPORTADOR  FAZENDA_COUNT
# 1     1       Rampazo              2
# 3     2       Pastori              2
# 7     3         Tover              2
# 8     4       Pastori              2
# 13    6       Pastori              2
# 16    7       Pastori              2
# 21    9       Pastori              2
# 23    9         Tover              2
# 25   10       Rampazo              2
# 27   11       Pastori              2
# 30   12       Rampazo              2
# 37   15       Rampazo              2
# 38   15         Tover              2
# 46   19       Pastori              2
# 50   20       Rampazo              2
# 51   20         Tover              2
# 53   21       Rampazo              2
# 54   21         Tover              2
# 61   24         Tover              2
# 65   26       Pastori              2
# 67   26         Tover              2
# 70   28       Pastori              2
# 73   29       Rampazo              2
# 74   30       Rampazo              2
# Incumplimiento UP >= 7000: UP S3AX01 tiene 4 entradas (máximo 2). Días: [2, 8, 9, 10, 15, 21]
# Incumplimiento UP < 7000: UP S3AX02 tiene 2 entradas (debe ser 1). Días: [11, 12, 18]
# Incumplimiento UP < 7000: UP S3AX03 tiene 2 entradas (debe ser 1). Días: [4, 10]
# Incumplimiento UP < 7000: UP S3AX06 iniciada pero no completada. Transportado: 5108.40, Total: 5568.94
# Incumplimiento UP < 7000: UP S3AX06 tiene 3 entradas (debe ser 1). Días: [1, 27, 28, 30]
# Incumplimiento UP >= 7000: UP S5AK05 tiene 4 entradas (máximo 2). Días: [2, 19, 25, 29]
# Incumplimiento UP >= 7000: UP S5AK08 tiene 7 entradas (máximo 2). Días: [4, 7, 11, 13, 15, 20, 23]
# Incumplimiento UP >= 7000: UP S5AK09 tiene 6 entradas (máximo 2). Días: [9, 10, 15, 21, 23, 26, 28, 29]
# Incumplimiento UP >= 7000: UP S5AK10 tiene 5 entradas (máximo 2). Días: [5, 6, 13, 24, 26, 31]
# Incumplimiento UP < 7000: UP S5AW05 tiene 4 entradas (debe ser 1). Días: [8, 12, 14, 17]
# Incumplimiento UP < 7000: UP S5AW09 tiene 4 entradas (debe ser 1). Días: [2, 6, 8, 22]
# Incumplimiento UP >= 7000: UP S5AW10 tiene 5 entradas (máximo 2). Días: [1, 4, 12, 20, 31]
# Incumplimiento UP >= 7000: UP S5AW13 tiene 3 entradas (máximo 2). Días: [1, 23, 29]
# Incumplimiento UP >= 7000: UP S5AW14 tiene 7 entradas (máximo 2). Días: [3, 5, 6, 16, 17, 19, 20, 22, 26, 30]
# Incumplimiento UP < 7000: UP S6BG08 tiene 2 entradas (debe ser 1). Días: [7, 20]
# Incumplimiento UP < 7000: UP S6BG11 tiene 2 entradas (debe ser 1). Días: [9, 22]
# Incumplimiento UP < 7000: UP S6BG13 iniciada pero no completada. Transportado: 3300.00, Total: 4300.00
# Incumplimiento UP < 7000: UP S6BG13 tiene 3 entradas (debe ser 1). Días: [3, 6, 25]
# Incumplimiento UP >= 7000: UP S6BX01 tiene 7 entradas (máximo 2). Días: [1, 9, 15, 17, 18, 20, 24, 31]
# Incumplimiento UP < 7000: UP S6C297 iniciada pero no completada. Transportado: 1801.80, Total: 4791.00
# Incumplimiento UP < 7000: UP S6C297 tiene 2 entradas (debe ser 1). Días: [8, 27]
# Incumplimiento UP < 7000: UP S6C298 iniciada pero no completada. Transportado: 2772.00, Total: 3700.00
# Incumplimiento UP < 7000: UP S6C298 tiene 3 entradas (debe ser 1). Días: [3, 5, 24]
# Incumplimiento UP < 7000: UP S6C334 iniciada pero no completada. Transportado: 2772.00, Total: 5974.00
# Incumplimiento UP < 7000: UP S6C334 tiene 2 entradas (debe ser 1). Días: [10, 26, 27]
# Incumplimiento UP < 7000: UP S6C421 iniciada pero no completada. Transportado: 4125.00, Total: 4500.00
# Incumplimiento UP < 7000: UP S6C421 tiene 4 entradas (debe ser 1). Días: [11, 13, 19, 26]
# Advertencia - Completitud Fazenda: Fazenda FORTALEZA iniciada pero no completada al final del horizonte. Transportado: 8177.40, Total: 22870.00
# Advertencia - Completitud Fazenda: Fazenda INDIANA II iniciada pero no completada al final del horizonte. Transportado: 22803.36, Total: 24684.00
# Advertencia - Completitud Fazenda: Fazenda PIRACEMA_GLEBA PULADOR - DX iniciada pero no completada al final del horizonte. Transportado: 28476.00, Total: 55869.74
# Advertencia - Completitud Fazenda: Fazenda SANTO ANTONIO SALIG. iniciada pero no completada al final del horizonte. Transportado: 7260.00, Total: 12700.00
# Advertencia - Completitud Fazenda: Fazenda SINIMBU iniciada pero no completada al final del horizonte. Transportado: 10455.00, Total: 21310.00
# Advertencia - Completitud Fazenda: Fazenda SIRIEMA iniciada pero no completada al final del horizonte. Transportado: 4125.00, Total: 4500.00
# Advertencia - Completitud Fazenda: Fazenda TURVO III (LEX) iniciada pero no completada al final del horizonte. Transportado: 28459.20, Total: 58790.26
# --- Validación Terminada ---
# >>> La solución NO CUMPLE con una o más restricciones.
# False

# %%
# --- Funciones Auxiliares ---
def calculate_daily_transport_volume(vehicles, caixa_carga, tempo_ciclo):
    """Calcula el volumen máximo que pueden transportar los vehículos en un día."""
    if vehicles <= 0 or caixa_carga <= 0 or tempo_ciclo <= 0:
        return 0
    return vehicles * caixa_carga * tempo_ciclo

def check_continuity(days_list):
    """Función auxiliar para verificar continuidad y número de bloques."""
    if not isinstance(days_list, list) or not days_list:
         return 0, True
    
    sorted_days = sorted(list(set(filter(None, days_list)))) # Filtra None o NaNs
    if not sorted_days:
      return 0, True

    blocks = 0
    if sorted_days:
        blocks = 1
        for i in range(len(sorted_days) - 1):
            if sorted_days[i+1] != sorted_days[i] + 1:
                blocks += 1
    is_continuous = (blocks <= 1) # Consideramos continuo si hay 0 o 1 bloque
    return blocks, is_continuous

# --- Heurística Constructiva ---

def constructive_heuristic(df_horizonte, df_bd_up, df_frota, df_grua, df_fabrica, df_rota):
    """
    Intenta construir una solución factible día por día.
    """
    schedule = [] # Lista para guardar las filas de la solución

    # --- Inicializar Estado ---
    up_status = df_bd_up.set_index('UP').copy() # Usar UP como índice para fácil acceso
    up_status['VOLUME_RESTANTE'] = up_status['VOLUME']
    # Inicializar DIAS_TRABAJADOS como una lista vacía para cada fila
    up_status['DIAS_TRABAJADOS'] = [[] for _ in range(len(up_status))]
    up_status['BLOQUES_TRABAJO'] = 0
    up_status['ESTADO'] = 'PENDIENTE' # PENDIENTE, ACTIVA, COMPLETADA, PAUSADA (>7000m3 only)

    # Estado del transportador por día (se resetea/actualiza cada día)
    transporter_daily_status = {t: {'fazenda_actual': None, 'ups_activas_hoy': [], 'vehiculos_usados_hoy': 0}
                                for t in df_frota['TRANSPORTADOR']}

    # Guardar la última Fazenda trabajada por un transportador para continuidad
    transporter_last_fazenda = {t: None for t in df_frota['TRANSPORTADOR']}


    print("--- Iniciando Heurística Constructiva ---")

    # --- Bucle Principal por Día ---
    for _, dia_info in df_horizonte.iterrows():
        dia = dia_info['DIA']
        mes = dia_info['MES']
        es_ciclo_lento = dia_info['CICLO_LENTO'] == 'X'
        print(f"\n--- Construyendo Día {dia} {'(Ciclo Lento)' if es_ciclo_lento else ''} ---")

        # Resetear estado diario (mantener fazenda si es necesario?)
        for t in transporter_daily_status:
            transporter_daily_status[t]['ups_activas_hoy'] = []
            transporter_daily_status[t]['vehiculos_usados_hoy'] = 0
            # ¿Debería mantenerse la fazenda_actual si no se completó? Sí.
            # transporter_daily_status[t]['fazenda_actual'] = None # Resetear o mantener?

        # Obtener demandas y límites del día
        fabrica_dia = df_fabrica[df_fabrica['DIA'] == dia].iloc[0]
        volumen_necesario_min = fabrica_dia['DEMANDA_MIN']
        volumen_acumulado_dia = 0

        # --- Priorización de UPs ---
        # 1. UPs Activas o Pausadas (que deben continuarse)
        # 2. UPs Pendientes
        # Podría añadirse más lógica (ej. por RSP para cumplir objetivo diario)
        ups_activas_pausadas = up_status[up_status['ESTADO'].isin(['ACTIVA', 'PAUSADA'])].index.tolist()
        ups_pendientes = up_status[up_status['ESTADO'] == 'PENDIENTE'].index.tolist()
        # Simple Prio: Activas/Pausadas primero, luego Pendientes (podría ordenarse mejor)
        ups_priorizadas = ups_activas_pausadas + ups_pendientes

        # --- Bucle por Transportador ---
        # Podríamos ordenar transportadores (ej. por capacidad) pero lo hacemos simple
        for transportador in df_frota['TRANSPORTADOR'].unique():
            
            transportador_info = df_frota[df_frota['TRANSPORTADOR'] == transportador].iloc[0]
            grua_info = df_grua[df_grua['TRANSPORTADOR'] == transportador].iloc[0]
            frota_min_transp = transportador_info['FROTA_MIN']
            frota_max_transp = transportador_info['FROTA_MAX']
            qtd_gruas_transp = grua_info['QTD_GRUAS']
            perc_min_vehi_up = grua_info['PORCENTAGEM_VEICULOS_MIN']
            
            vehiculos_disponibles_transp = frota_max_transp # Empezar con el máximo posible
            
            # --- Determinar Fazenda Objetivo ---
            fazenda_objetivo = None
            # Si el transportador estaba activo en una Fazenda ayer y no la completó, DEBE continuarla.
            fazenda_previa = transporter_last_fazenda[transportador]
            if fazenda_previa:
                 ups_en_fazenda_previa = up_status[up_status['FAZENDA'] == fazenda_previa]
                 # Si *alguna* UP en esa fazenda está ACTIVA o PAUSADA, debe continuarla.
                 if any(ups_en_fazenda_previa['ESTADO'].isin(['ACTIVA', 'PAUSADA'])):
                     fazenda_objetivo = fazenda_previa
                     print(f"  {transportador} debe continuar Fazenda: {fazenda_objetivo}")
            
            # Si no hay obligación de continuar, buscar una nueva Fazenda (o continuar una opcionalmente)
            if not fazenda_objetivo:
                 # Estrategia simple: Elegir la primera fazenda con UPs pendientes/activas que pueda atender
                 possible_fazendas = up_status[up_status.index.isin(ups_priorizadas)]['FAZENDA'].unique()
                 for f in possible_fazendas:
                     # Verificar si hay ruta para *alguna* UP en esa fazenda
                     ups_in_f = up_status[(up_status['FAZENDA'] == f) & (up_status.index.isin(ups_priorizadas))].index
                     if any(not df_rota[(df_rota['ORIGEM'] == up) & (df_rota['TRANSPORTADOR'] == transportador)].empty for up in ups_in_f):
                          fazenda_objetivo = f
                          print(f"  {transportador} elige nueva Fazenda: {fazenda_objetivo}")
                          break # Elegir la primera encontrada

            if not fazenda_objetivo:
                print(f"  {transportador} no encontró Fazenda objetivo hoy.")
                transporter_last_fazenda[transportador] = None # No trabajó
                continue # Siguiente transportador
                
            transporter_daily_status[transportador]['fazenda_actual'] = fazenda_objetivo
            transporter_last_fazenda[transportador] = fazenda_objetivo # Actualizar la última trabajada

            # --- Seleccionar UPs dentro de la Fazenda Objetivo ---
            ups_seleccionadas_hoy = []
            # Filtrar UPs priorizadas que estén en la fazenda objetivo
            ups_candidatas_fazenda = [up for up in ups_priorizadas if up_status.loc[up, 'FAZENDA'] == fazenda_objetivo]

            for up_id in ups_candidatas_fazenda:
                if len(ups_seleccionadas_hoy) >= qtd_gruas_transp:
                    break # Límite de grúas alcanzado

                # Verificar si hay ruta
                rota_info = df_rota[(df_rota['ORIGEM'] == up_id) & (df_rota['TRANSPORTADOR'] == transportador)]
                if rota_info.empty:
                    continue

                # Verificar Reglas de Completitud/Fragmentación ANTES de añadir
                up_data = up_status.loc[up_id]
                vol_total = up_data['VOLUME']
                vol_restante = up_data['VOLUME_RESTANTE']
                estado_actual = up_data['ESTADO']
                bloques_actuales = up_data['BLOQUES_TRABAJO']

                if vol_restante <= 0: continue # Ya completada

                puede_empezar_o_continuar = False
                if estado_actual == 'PENDIENTE':
                    # Si es pequeña (<7000), solo puede empezar si se puede terminar hoy (simplificación: difícil saber a priori)
                    # Omitimos esa check compleja por ahora y permitimos empezar.
                    # Si es grande (>=7000), puede empezar si bloques < 2
                    if vol_total < 7000:
                         puede_empezar_o_continuar = True # Asumimos que puede empezar
                    elif bloques_actuales < 2:
                         puede_empezar_o_continuar = True
                elif estado_actual == 'ACTIVA':
                     puede_empezar_o_continuar = True # Puede continuar
                elif estado_actual == 'PAUSADA':
                     # Solo puede continuar si bloques < 2
                     if bloques_actuales < 2:
                          puede_empezar_o_continuar = True

                if puede_empezar_o_continuar:
                    ups_seleccionadas_hoy.append(up_id)

            if not ups_seleccionadas_hoy:
                print(f"  {transportador} no encontró UPs viables en {fazenda_objetivo} hoy.")
                # Si no hay UPs viables, ¿la fazenda se considera 'no trabajada' para el día siguiente?
                # Si la empezó pero no pudo trabajar, debería seguir asignada? Depende de la regla estricta.
                # Asumimos que si no asigna UPs, no trabajó la fazenda ese día.
                # transporter_last_fazenda[transportador] = None # Comentado: mantenerla asignada si fue obligatoria?
                continue

            print(f"  {transportador} en {fazenda_objetivo} -> UPs: {ups_seleccionadas_hoy}")

            # --- Asignar Vehículos y Calcular Volumen ---
            num_ups_asignadas = len(ups_seleccionadas_hoy)
            vehiculos_total_asignar = 0

            # Intentar asignar al menos el mínimo de flota, distribuido
            min_vehiculos_necesarios = 0
            if num_ups_asignadas > 0:
                 # Cada UP necesita al menos ceil(frota_min * perc_min) vehículos? No, el % es sobre el total *usado*.
                 # Empecemos asignando la flota mínima total y distribuirla
                 vehiculos_total_asignar = frota_min_transp
                 # Asegurar que no exceda el máximo
                 vehiculos_total_asignar = min(vehiculos_total_asignar, frota_max_transp)

            # Distribución simple (podría ser proporcional al volumen restante, etc.)
            vehiculos_por_up = {}
            if num_ups_asignadas > 0:
                base_vehi_por_up = vehiculos_total_asignar // num_ups_asignadas
                resto = vehiculos_total_asignar % num_ups_asignadas
                
                idx = 0
                for up_id in ups_seleccionadas_hoy:
                     vehi_up = base_vehi_por_up + (1 if idx < resto else 0)
                     # Validar MIN PORCENTAJE: Esta UP debe tener >= vehiculos_total_asignar * perc_min_vehi_up
                     min_req_up = math.ceil(vehiculos_total_asignar * perc_min_vehi_up)
                     if vehi_up < min_req_up:
                         # No cumple, ¿qué hacer? ¿Aumentar el total? ¿Redistribuir?
                         # Simplificación: Por ahora, lo dejamos (puede causar infactibilidad)
                         print(f"Advertencia: {up_id} podría no cumplir % min vehiculos ({vehi_up} < {min_req_up})")
                         pass 
                     
                     # Verificar si con estos vehículos se puede transportar *algo*
                     rota_info = df_rota[(df_rota['ORIGEM'] == up_id) & (df_rota['TRANSPORTADOR'] == transportador)].iloc[0]
                     caixa = rota_info['CAIXA_CARGA']
                     ciclo = rota_info['TEMPO_CICLO'] # TODO: Ajustar por ciclo lento? (PDF no especifica cómo)
                     vol_potencial_up = calculate_daily_transport_volume(vehi_up, caixa, ciclo)
                     
                     if vol_potencial_up > 0:
                         vehiculos_por_up[up_id] = vehi_up
                     else:
                         print(f"Advertencia: Asignación de {vehi_up} vehiculos a {up_id} no transporta volumen.")
                         # Quitarla de la lista de activas para hoy?
                         
                # Recalcular UPs activas y vehículos totales usados hoy
                ups_seleccionadas_hoy = list(vehiculos_por_up.keys())
                vehiculos_usados_transp_hoy = sum(vehiculos_por_up.values())
                
                # Validar flota total usada hoy
                if not (frota_min_transp <= vehiculos_usados_transp_hoy <= frota_max_transp):
                     print(f"Error interno: Flota calculada ({vehiculos_usados_transp_hoy}) fuera de rango [{frota_min_transp}, {frota_max_transp}] para {transportador}")
                     # Aquí deberíamos tener una lógica para ajustar la asignación, pero es complejo.
                     # Por ahora, continuamos pero la solución será infactible.
                     pass

                transporter_daily_status[transportador]['vehiculos_usados_hoy'] = vehiculos_usados_transp_hoy
                transporter_daily_status[transportador]['ups_activas_hoy'] = ups_seleccionadas_hoy

            # --- Calcular Volumen Transportado y Actualizar Estado ---
            for up_id in ups_seleccionadas_hoy:
                vehi_up = vehiculos_por_up[up_id]
                up_data = up_status.loc[up_id] # Obtener datos actuales
                rota_info = df_rota[(df_rota['ORIGEM'] == up_id) & (df_rota['TRANSPORTADOR'] == transportador)].iloc[0]
                caixa = rota_info['CAIXA_CARGA']
                ciclo = rota_info['TEMPO_CICLO'] # TODO: Ajustar ciclo lento
                
                vol_max_transportable_hoy = calculate_daily_transport_volume(vehi_up, caixa, ciclo)
                vol_real_transportado = min(vol_max_transportable_hoy, up_data['VOLUME_RESTANTE'])

                if vol_real_transportado > 0:
                    # Actualizar volumen restante
                    up_status.loc[up_id, 'VOLUME_RESTANTE'] -= vol_real_transportado

                    # --- Inicialización Segura de dias_previos ---
                    try:
                        # Intenta obtener la lista actual
                        retrieved_days = up_status.loc[up_id, 'DIAS_TRABAJADOS']
                        # Verifica si es una lista válida, si no, inicializa como vacía
                        if isinstance(retrieved_days, list):
                            dias_previos = retrieved_days.copy() # Usar .copy() por seguridad
                        else:
                            dias_previos = []
                    except KeyError:
                        # Error si up_id no existe (no debería pasar aquí, pero por seguridad)
                        print(f"Error Crítico: UP {up_id} no encontrado en up_status index.")
                        dias_previos = []
                    except Exception as e:
                            # Cualquier otro error inesperado al leer
                            print(f"Error inesperado al leer DIAS_TRABAJADOS para {up_id}: {e}")
                            dias_previos = []
                    # --- Fin Inicialización Segura ---

                    # Ahora estamos seguros de que 'dias_previos' es una lista

                    nuevo_estado = 'ACTIVA'

                    # Verificar si es un nuevo bloque de trabajo
                    # Un bloque nuevo empieza si la lista estaba vacía O si el día actual no es consecutivo al último registrado
                    is_new_block = False
                    if not dias_previos: # Es el primer día que se trabaja esta UP
                        is_new_block = True
                    elif dia != dias_previos[-1] + 1: # Hubo una interrupción (día no consecutivo)
                        is_new_block = True

                    # Incrementar contador de bloques SOLO si es un nuevo bloque Y NO es el primer día en absoluto
                    if is_new_block and dias_previos:
                        # Asegúrate de que BLOQUES_TRABAJO exista y sea numérico
                            if pd.isna(up_status.loc[up_id, 'BLOQUES_TRABAJO']):
                                up_status.loc[up_id, 'BLOQUES_TRABAJO'] = 0
                            up_status.loc[up_id, 'BLOQUES_TRABAJO'] += 1

                    # Añadir día actual a la lista si no está ya (por si acaso)
                    if dia not in dias_previos:
                        dias_previos.append(dia)
                        # Opcional: Mantener la lista ordenada, aunque no debería ser necesario si los días se procesan en orden
                        # dias_previos.sort()

                    # Reasignar la lista actualizada usando .at para seguridad
                    up_status.at[up_id, 'DIAS_TRABAJADOS'] = dias_previos

                    # Actualizar estado final de la UP para hoy
                    if up_status.loc[up_id, 'VOLUME_RESTANTE'] <= 1e-6: # Usar tolerancia para flotantes
                        nuevo_estado = 'COMPLETADA'
                    # (Podrías añadir lógica para PAUSADA si es UP grande y se interrumpe, pero la dejaremos ACTIVA por ahora)
                    up_status.loc[up_id, 'ESTADO'] = nuevo_estado

                    # Añadir la entrada al schedule (DataFrame final)
                    schedule.append({
                        'UP': up_id,
                        'FAZENDA': up_data['FAZENDA'], # Necesitas obtener up_data antes en el loop
                        'TRANSPORTADOR': transportador,
                        'DIA': dia,
                        'MES': mes,
                        'DB': up_data['DB'],      # Necesitas obtener up_data antes en el loop
                        'RSP': up_data['RSP'],     # Necesitas obtener up_data antes en el loop
                        'QTD_VEICULOS': vehi_up,
                        'VOLUME': vol_real_transportado
                    })
                    volumen_acumulado_dia += vol_real_transportado
                    print(f"    -> {transportador} transporta {vol_real_transportado:.2f} m³ desde {up_id} ({nuevo_estado})")

                # else: # vol_real_transportado <= 0
                    # No se transportó nada desde esta UP hoy
                    # ¿Deberíamos actualizar el estado si estaba ACTIVA? Quizás a PAUSADA?
                    # Depende de la interpretación de las reglas. Por ahora no hacemos nada.
                    # pass

                    up_status.loc[up_id, 'ESTADO'] = nuevo_estado

                    # Añadir al schedule
                    schedule.append({
                        'UP': up_id,
                        'FAZENDA': up_data['FAZENDA'],
                        'TRANSPORTADOR': transportador,
                        'DIA': dia,
                        'MES': mes,
                        'DB': up_data['DB'],
                        'RSP': up_data['RSP'],
                        'QTD_VEICULOS': vehi_up,
                        'VOLUME': vol_real_transportado
                    })
                    volumen_acumulado_dia += vol_real_transportado
                    print(f"    -> {transportador} transporta {vol_real_transportado:.2f} m³ desde {up_id} ({nuevo_estado})")

        # --- Fin del Bucle de Transportadores ---
        print(f"  Volumen total transportado día {dia}: {volumen_acumulado_dia:.2f} (Objetivo: [{volumen_necesario_min}, {fabrica_dia['DEMANDA_MAX']}])")
        # TODO: Podríamos añadir una segunda pasada o lógica de ajuste si no se cumple demanda/RSP

    # --- Fin del Horizonte ---
    final_schedule_df = pd.DataFrame(schedule)

    # Validar la solución completa al final
    print("\nValidando la solución construida:")
    # Asumiendo que las funciones de validación están definidas como en la respuesta anterior
    try:
        # Recrear las funciones de validación aquí si no están en el mismo scope
        # O importarlas si están en otro módulo
        validate_all_constraints(final_schedule_df, df_fabrica, df_frota, df_grua, df_bd_up)
    except NameError:
        print("Advertencia: Funciones de validación no encontradas. Ejecútalas por separado.")


    print("--- Heurística Constructiva Terminada ---")
    return final_schedule_df

# --- Ejemplo de Ejecución ---
# Necesitas tener los DataFrames (df_horizonte, df_bd_up, etc.) cargados previamente.
# Y las funciones de validación definidas.

# print("Ejecutando heurística constructiva...")
# df_solucion_construida = constructive_heuristic(df_horizonte, df_bd_up, df_frota, df_grua, df_fabrica, df_rota)
# print("\nSolución Construida (primeras filas):")
# print(df_solucion_construida.head())
# print("\nSolución Construida (últimas filas):")
# print(df_solucion_construida.tail())

# Guardar a CSV (opcional)
# df_solucion_construida.to_csv("solucion_construida.csv", index=False, sep=';', decimal=',')
# print("\nSolución construida guardada en 'solucion_construida.csv'")

# %%
# --- Ejemplo de Ejecución ---
# Necesitas tener los DataFrames (df_horizonte, df_bd_up, etc.) cargados previamente.
# Y las funciones de validación definidas.

print("Ejecutando heurística constructiva...")
df_solucion_construida = constructive_heuristic(df_horizonte, df_bd_up, df_frota, df_grua, df_fabrica, df_rota)
print("\nSolución Construida (primeras filas):")
print(df_solucion_construida.head())
print("\nSolución Construida (últimas filas):")
print(df_solucion_construida.tail())

# Guardar a CSV (opcional)
# df_solucion_construida.to_csv("solucion_construida.csv", index=False, sep=';', decimal=',')
# print("\nSolución construida guardada en 'solucion_construida.csv'")
# Out:
# Ejecutando heurística constructiva...
# --- Iniciando Heurística Constructiva ---
#
# --- Construyendo Día 1 (Ciclo Lento) ---
#   Pastori elige nueva Fazenda: INDIANA II
#   Pastori en INDIANA II -> UPs: ['S3AX03', 'S3AX04']
#     -> Pastori transporta 1544.40 m³ desde S3AX03 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX03 (ACTIVA)
#     -> Pastori transporta 1300.00 m³ desde S3AX04 (COMPLETADA)
#     -> Pastori transporta 1300.00 m³ desde S3AX04 (COMPLETADA)
#   Tover elige nueva Fazenda: SIRIEMA
#   Tover en SIRIEMA -> UPs: ['S6C421']
#     -> Tover transporta 1980.00 m³ desde S6C421 (ACTIVA)
#     -> Tover transporta 1980.00 m³ desde S6C421 (ACTIVA)
#   Rampazo elige nueva Fazenda: INDIANA II
#   Rampazo en INDIANA II -> UPs: ['S3AX03', 'S3AX02']
#     -> Rampazo transporta 579.67 m³ desde S3AX03 (COMPLETADA)
#     -> Rampazo transporta 579.67 m³ desde S3AX03 (COMPLETADA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX02 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX02 (ACTIVA)
#   Volumen total transportado día 1: 13184.14 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 2  ---
#   Pastori debe continuar Fazenda: INDIANA II
#   Pastori en INDIANA II -> UPs: ['S3AX02', 'S3AX01']
#     -> Pastori transporta 1544.40 m³ desde S3AX02 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX02 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#   Tover debe continuar Fazenda: SIRIEMA
#   Tover en SIRIEMA -> UPs: ['S6C421']
#     -> Tover transporta 1980.00 m³ desde S6C421 (ACTIVA)
#     -> Tover transporta 1980.00 m³ desde S6C421 (ACTIVA)
#   Rampazo debe continuar Fazenda: INDIANA II
#   Rampazo en INDIANA II -> UPs: ['S3AX02', 'S3AX01']
#     -> Rampazo transporta 1084.09 m³ desde S3AX02 (COMPLETADA)
#     -> Rampazo transporta 1084.09 m³ desde S3AX02 (COMPLETADA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX01 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX01 (ACTIVA)
#   Volumen total transportado día 2: 14681.78 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 3  ---
#   Pastori debe continuar Fazenda: INDIANA II
#   Pastori en INDIANA II -> UPs: ['S3AX01', 'S3AX06']
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX06 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX06 (ACTIVA)
#   Tover debe continuar Fazenda: SIRIEMA
#   Tover en SIRIEMA -> UPs: ['S6C421']
#     -> Tover transporta 540.00 m³ desde S6C421 (COMPLETADA)
#     -> Tover transporta 540.00 m³ desde S6C421 (COMPLETADA)
#   Rampazo debe continuar Fazenda: INDIANA II
#   Rampazo en INDIANA II -> UPs: ['S3AX01', 'S3AX06']
#     -> Rampazo transporta 1188.00 m³ desde S3AX01 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX01 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX06 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX06 (ACTIVA)
#   Volumen total transportado día 3: 12009.60 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 4  ---
#   Pastori debe continuar Fazenda: INDIANA II
#   Pastori en INDIANA II -> UPs: ['S3AX01', 'S3AX06']
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX06 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX06 (ACTIVA)
#   Tover elige nueva Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C297', 'S6C334']
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#   Rampazo debe continuar Fazenda: INDIANA II
#   Rampazo en INDIANA II -> UPs: ['S3AX01', 'S3AX06']
#     -> Rampazo transporta 1188.00 m³ desde S3AX01 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX01 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX06 (ACTIVA)
#     -> Rampazo transporta 1188.00 m³ desde S3AX06 (ACTIVA)
#   Volumen total transportado día 4: 14256.00 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 5  ---
#   Pastori debe continuar Fazenda: INDIANA II
#   Pastori en INDIANA II -> UPs: ['S3AX01', 'S3AX06']
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 1544.40 m³ desde S3AX01 (ACTIVA)
#     -> Pastori transporta 104.14 m³ desde S3AX06 (COMPLETADA)
#     -> Pastori transporta 104.14 m³ desde S3AX06 (COMPLETADA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C297', 'S6C334']
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#   Rampazo debe continuar Fazenda: INDIANA II
#   Rampazo en INDIANA II -> UPs: ['S3AX01']
#     -> Rampazo transporta 2132.90 m³ desde S3AX01 (COMPLETADA)
#     -> Rampazo transporta 2132.90 m³ desde S3AX01 (COMPLETADA)
#   Volumen total transportado día 5: 10889.28 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 6  ---
#   Pastori elige nueva Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW09']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW09 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW09 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C297', 'S6C334']
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#   Rampazo elige nueva Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW09']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW09 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW09 (ACTIVA)
#   Volumen total transportado día 6: 12434.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 7  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW09']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1043.00 m³ desde S5AW09 (COMPLETADA)
#     -> Pastori transporta 1043.00 m³ desde S5AW09 (COMPLETADA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C297', 'S6C334']
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 7: 11946.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 8 (Ciclo Lento) ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C297', 'S6C334']
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C297 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 8: 12434.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 9  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C297', 'S6C334']
#     -> Tover transporta 633.00 m³ desde S6C297 (COMPLETADA)
#     -> Tover transporta 633.00 m³ desde S6C297 (COMPLETADA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 9: 12037.20 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 10  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C334', 'S6C335']
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C334 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 10: 12434.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 11  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C334', 'S6C335']
#     -> Tover transporta 152.80 m³ desde S6C334 (COMPLETADA)
#     -> Tover transporta 152.80 m³ desde S6C334 (COMPLETADA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 11: 11076.80 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 12  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335', 'S6C298']
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 12: 12434.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 13  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW14 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335', 'S6C298']
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW14 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW13 (ACTIVA)
#   Volumen total transportado día 13: 12434.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 14  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW14', 'S5AW13']
#     -> Pastori transporta 317.08 m³ desde S5AW14 (COMPLETADA)
#     -> Pastori transporta 317.08 m³ desde S5AW14 (COMPLETADA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW13 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335', 'S6C298']
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW13', 'S5AW05']
#     -> Rampazo transporta 341.54 m³ desde S5AW13 (COMPLETADA)
#     -> Rampazo transporta 341.54 m³ desde S5AW13 (COMPLETADA)
#     -> Rampazo transporta 990.00 m³ desde S5AW05 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW05 (ACTIVA)
#   Volumen total transportado día 14: 9197.64 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 15 (Ciclo Lento) ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW05', 'S5AW10']
#     -> Pastori transporta 1287.00 m³ desde S5AW05 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW05 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW10 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW10 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335', 'S6C298']
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C298 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW05', 'S5AW10']
#     -> Rampazo transporta 990.00 m³ desde S5AW05 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW05 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW10 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW10 (ACTIVA)
#   Volumen total transportado día 15: 12434.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 16  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW05', 'S5AW10']
#     -> Pastori transporta 1287.00 m³ desde S5AW05 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW05 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW10 (ACTIVA)
#     -> Pastori transporta 1287.00 m³ desde S5AW10 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335', 'S6C298']
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 831.60 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 373.60 m³ desde S6C298 (COMPLETADA)
#     -> Tover transporta 373.60 m³ desde S6C298 (COMPLETADA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW05', 'S5AW10']
#     -> Rampazo transporta 406.00 m³ desde S5AW05 (COMPLETADA)
#     -> Rampazo transporta 406.00 m³ desde S5AW05 (COMPLETADA)
#     -> Rampazo transporta 990.00 m³ desde S5AW10 (ACTIVA)
#     -> Rampazo transporta 990.00 m³ desde S5AW10 (ACTIVA)
#   Volumen total transportado día 16: 10350.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 17  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW10']
#     -> Pastori transporta 2475.00 m³ desde S5AW10 (ACTIVA)
#     -> Pastori transporta 2475.00 m³ desde S5AW10 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335']
#     -> Tover transporta 1663.20 m³ desde S6C335 (ACTIVA)
#     -> Tover transporta 1663.20 m³ desde S6C335 (ACTIVA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW10']
#     -> Rampazo transporta 1881.00 m³ desde S5AW10 (ACTIVA)
#     -> Rampazo transporta 1881.00 m³ desde S5AW10 (ACTIVA)
#   Volumen total transportado día 17: 12038.40 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 18  ---
#   Pastori debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Pastori en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW10']
#     -> Pastori transporta 2475.00 m³ desde S5AW10 (ACTIVA)
#     -> Pastori transporta 2475.00 m³ desde S5AW10 (ACTIVA)
#   Tover debe continuar Fazenda: FORTALEZA
#   Tover en FORTALEZA -> UPs: ['S6C335']
#     -> Tover transporta 920.60 m³ desde S6C335 (COMPLETADA)
#     -> Tover transporta 920.60 m³ desde S6C335 (COMPLETADA)
#   Rampazo debe continuar Fazenda: PIRACEMA_GLEBA PULADOR - DX
#   Rampazo en PIRACEMA_GLEBA PULADOR - DX -> UPs: ['S5AW10']
#     -> Rampazo transporta 1391.12 m³ desde S5AW10 (COMPLETADA)
#     -> Rampazo transporta 1391.12 m³ desde S5AW10 (COMPLETADA)
#   Volumen total transportado día 18: 9573.44 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 19  ---
#   Pastori elige nueva Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#   Tover elige nueva Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo elige nueva Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#   Volumen total transportado día 19: 11985.60 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 20  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#   Volumen total transportado día 20: 11985.60 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 21  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#   Volumen total transportado día 21: 11985.60 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 22 (Ciclo Lento) ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK05 (ACTIVA)
#   Volumen total transportado día 22: 11985.60 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 23  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK05 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK05']
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 128.26 m³ desde S5AK05 (COMPLETADA)
#     -> Rampazo transporta 128.26 m³ desde S5AK05 (COMPLETADA)
#   Volumen total transportado día 23: 10394.12 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 24  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK09']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK09']
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK10 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#   Volumen total transportado día 24: 11985.60 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 25  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK09']
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK10 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#     -> Tover transporta 1742.40 m³ desde S6BX01 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK10', 'S5AK09']
#     -> Rampazo transporta 47.60 m³ desde S5AK10 (COMPLETADA)
#     -> Rampazo transporta 47.60 m³ desde S5AK10 (COMPLETADA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#   Volumen total transportado día 25: 10232.80 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 26  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#   Tover debe continuar Fazenda: SANTO ANTONIO SALIG.
#   Tover en SANTO ANTONIO SALIG. -> UPs: ['S6BX01']
#     -> Tover transporta 503.20 m³ desde S6BX01 (COMPLETADA)
#     -> Tover transporta 503.20 m³ desde S6BX01 (COMPLETADA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#   Volumen total transportado día 26: 9507.20 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 27  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#   Tover elige nueva Fazenda: SINIMBU
#   Tover en SINIMBU -> UPs: ['S6BG12', 'S6BG08']
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG08 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG08 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#   Volumen total transportado día 27: 12460.80 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 28  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#   Tover debe continuar Fazenda: SINIMBU
#   Tover en SINIMBU -> UPs: ['S6BG12', 'S6BG08']
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 970.00 m³ desde S6BG08 (COMPLETADA)
#     -> Tover transporta 970.00 m³ desde S6BG08 (COMPLETADA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#   Volumen total transportado día 28: 12420.80 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 29  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#   Tover debe continuar Fazenda: SINIMBU
#   Tover en SINIMBU -> UPs: ['S6BG12', 'S6BG11']
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG11 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG11 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#   Volumen total transportado día 29: 12460.80 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 30  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#   Tover debe continuar Fazenda: SINIMBU
#   Tover en SINIMBU -> UPs: ['S6BG12', 'S6BG11']
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 160.00 m³ desde S6BG11 (COMPLETADA)
#     -> Tover transporta 160.00 m³ desde S6BG11 (COMPLETADA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#   Volumen total transportado día 30: 10800.80 (Objetivo: [6400, 8000])
#
# --- Construyendo Día 31  ---
#   Pastori debe continuar Fazenda: TURVO III (LEX)
#   Pastori en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK09 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#     -> Pastori transporta 1201.20 m³ desde S5AK08 (ACTIVA)
#   Tover debe continuar Fazenda: SINIMBU
#   Tover en SINIMBU -> UPs: ['S6BG12', 'S6BG10']
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG12 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG10 (ACTIVA)
#     -> Tover transporta 990.00 m³ desde S6BG10 (ACTIVA)
#   Rampazo debe continuar Fazenda: TURVO III (LEX)
#   Rampazo en TURVO III (LEX) -> UPs: ['S5AK09', 'S5AK08']
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK09 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#     -> Rampazo transporta 924.00 m³ desde S5AK08 (ACTIVA)
#   Volumen total transportado día 31: 12460.80 (Objetivo: [6400, 8000])
#
# Validando la solución construida:
# --- Iniciando Validación de Restricciones ---
# Incumplimiento - Demanda Diaria:
#     DIA    VOLUME  DEMANDA_MIN  DEMANDA_MAX
# 0     1  13184.14         6400         8000
# 1     2  14681.78         6400         8000
# 2     3  12009.60         6400         8000
# 3     4  14256.00         6400         8000
# 4     5  10889.28         6400         8000
# 5     6  12434.40         6400         8000
# 6     7  11946.40         6400         8000
# 7     8  12434.40         6400         8000
# 8     9  12037.20         6400         8000
# 9    10  12434.40         6400         8000
# 10   11  11076.80         6400         8000
# 11   12  12434.40         6400         8000
# 12   13  12434.40         6400         8000
# 13   14   9197.64         6400         8000
# 14   15  12434.40         6400         8000
# 15   16  10350.40         6400         8000
# 16   17  12038.40         6400         8000
# 17   18   9573.44         6400         8000
# 18   19  11985.60         6400         8000
# 19   20  11985.60         6400         8000
# 20   21  11985.60         6400         8000
# 21   22  11985.60         6400         8000
# 22   23  10394.12         6400         8000
# 23   24  11985.60         6400         8000
# 24   25  10232.80         6400         8000
# 25   26   9507.20         6400         8000
# 26   27  12460.80         6400         8000
# 27   28  12420.80         6400         8000
# 28   29  12460.80         6400         8000
# 29   30  10800.80         6400         8000
# 30   31  12460.80         6400         8000
# Incumplimiento - RSP Diario:
#     DIA   RSP_AVG  RSP_MIN  RSP_MAX
# 0     1  1.382462      1.4     1.49
# 2     3  1.525029      1.4     1.49
# 3     4  1.522207      1.4     1.49
# 4     5  1.512906      1.4     1.49
# 25   26  1.506539      1.4     1.49
# 26   27  1.520450      1.4     1.49
# 27   28  1.520404      1.4     1.49
# 28   29  1.521706      1.4     1.49
# 29   30  1.518500      1.4     1.49
# 30   31  1.522485      1.4     1.49
# Incumplimiento - Tamaño Flota Transportador:
#     DIA TRANSPORTADOR  QTD_VEICULOS  FROTA_MIN  FROTA_MAX
# 0     1       Pastori            52         25         27
# 1     2       Pastori            52         25         27
# 2     3       Pastori            52         25         27
# 3     4       Pastori            52         25         27
# 4     5       Pastori            52         25         27
# ..  ...           ...           ...        ...        ...
# 88   27         Tover            24         12         14
# 89   28         Tover            24         12         14
# 90   29         Tover            24         12         14
# 91   30         Tover            24         12         14
# 92   31         Tover            24         12         14
#
# [93 rows x 5 columns]
# Advertencia - Completitud Fazenda: Fazenda SINIMBU iniciada pero no completada al final del horizonte. Transportado: 18100.00, Total: 21310.00
# --- Validación Terminada ---
# >>> La solución NO CUMPLE con una o más restricciones.
# --- Heurística Constructiva Terminada ---
#
# Solución Construida (primeras filas):
#        UP     FAZENDA TRANSPORTADOR  DIA  MES          DB       RSP  \
# 0  S3AX03  INDIANA II       Pastori    1    5  410.081889  1.302226
# 1  S3AX03  INDIANA II       Pastori    1    5  410.081889  1.302226
# 2  S3AX04  INDIANA II       Pastori    1    5  471.026798  1.511823
# 3  S3AX04  INDIANA II       Pastori    1    5  471.026798  1.511823
# 4  S6C421     SIRIEMA         Tover    1    5  406.666302  1.289003
#
#    QTD_VEICULOS  VOLUME  RSP_WEIGHTED_SUM
# 0            13  1544.4       2011.158072
# 1            13  1544.4       2011.158072
# 2            13  1300.0       1965.370275
# 3            13  1300.0       1965.370275
# 4            12  1980.0       2552.225411
#
# Solución Construida (últimas filas):
#          UP          FAZENDA TRANSPORTADOR  DIA  MES          DB       RSP  \
# 331  S6BG10          SINIMBU         Tover   31    5  479.650625  1.547472
# 332  S5AK09  TURVO III (LEX)       Rampazo   31    5  485.001740  1.513740
# 333  S5AK09  TURVO III (LEX)       Rampazo   31    5  485.001740  1.513740
# 334  S5AK08  TURVO III (LEX)       Rampazo   31    5  484.253826  1.515094
# 335  S5AK08  TURVO III (LEX)       Rampazo   31    5  484.253826  1.515094
#
#      QTD_VEICULOS  VOLUME  RSP_WEIGHTED_SUM
# 331             6   990.0       1531.996953
# 332            10   924.0       1398.695344
# 333            10   924.0       1398.695344
# 334            10   924.0       1399.946583
# 335            10   924.0       1399.946583
